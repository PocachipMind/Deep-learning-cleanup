# %%
# !pip install graphrag

# %%
from pathlib import Path

working_dir = Path('working_directory')
working_dir.mkdir(parents=True, exist_ok=True)

# %%
# !graphrag init --root ./working_directory
# Out:
# ⠋ GraphRAG Indexer
# Initializing project at
# C:\Users\User\Desktop\DeepLearning\17번\langchain-tutorial-main\Ch05.
# GraphRAG\working_directory
# ⠋ GraphRAG Indexer

# %%
# 워킹 디렉토리 안에 input폴더 생성
input_dir = working_dir / 'input'
input_dir.mkdir(parents=True, exist_ok=True)

# %%
import shutil
import os
# from google.colab import drive

# 먼저 구글 드라이브 마운트
# drive.mount('/content/drive')

# 소스 및 대상 경로 정의
source_path = './Data/How_to_invest_money.txt'
destination_path = './working_directory/input/How_to_invest_money.txt'

# 파일 복사
shutil.copy(source_path, destination_path)

# 파일이 성공적으로 복사되었는지 확인
if os.path.exists(destination_path):
    print(f"파일이 {destination_path}에 성공적으로 복사되었습니다")
else:
    print("파일 복사 실패")
# Out:
# 파일이 ./working_directory/input/How_to_invest_money.txt에 성공적으로 복사되었습니다

# %%
# !graphrag index --root ./working_directory
# Out:
# ⠋ GraphRAG Indexer
# Logging enabled at
# C:\Users\User\Desktop\DeepLearning\17번\langchain-tutorial-main\Ch05.
# GraphRAG\working_directory\logs\indexing-engine.log
# ⠋ GraphRAG Indexer
# ⠹ GraphRAG Indexer
# 🚀 LLM Config Params Validated
# ⠏ GraphRAG Indexer
# ⠴ GraphRAG Indexer
# 🚀 Embedding LLM Config Params Validated
# ⠧ GraphRAG Indexer
# ⠧ GraphRAG Indexer
# Running standard indexing.
# ⠇ GraphRAG Indexer
# └── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# 🚀 create_base_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
#                                                     id  ... n_tokens
# 0    7a17fa7360ff1646ca4683384ceb616e20e1ed70c35f4d...  ...      300
# 1    d622a9906b41290d8195b66f751e34a17876b2fc65210f...  ...      300
# 2    20eda504be9853e5ddd93d6f5fa0a54ea639d58decbd4b...  ...      300
# 3    4c44882eb785628ae564fc7628f879705e19cc2c73d656...  ...      300
# 4    9db4b517df282c884b1e015bd3ae2b7bec3b26498c5c0b...  ...      300
# ..                                                 ...  ...      ...
# 151  6a913be02aa839d968be590f6ae0b507d4ac646228f2ac...  ...      300
# 152  cdd76e9f3ab4cab0b3e00fe2f8407d316b7a76e243031a...  ...      300
# 153  34c815fec7550459d4cd710d8d4650a94a9b25f1cc44e4...  ...      300
# 154  85ca60895cbbe8aac606c59073f2846d75dba4ee78dbce...  ...      300
# 155  91ff3176f0a613e0398839419ecc41b2a335dc74f56cc9...  ...      267
#
# [156 rows x 4 columns]
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# 🚀 create_final_documents
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
#                                                   id  ...  metadata
# 0  76b874f8ddf312c5c5d34517a4587852e8ef79438600b1...  ...       NaN
#
# [1 rows x 7 columns]
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ----------------------------------------   1% -:--:-- 0:00:00
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph - --------------------------------------   3% 0:00:02 0:00:00
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph - --------------------------------------   3% 0:00:02 0:00:01
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph - --------------------------------------   3% 0:00:02 0:00:02
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph - --------------------------------------   3% 0:00:02 0:00:03
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph - --------------------------------------   3% 0:02:37 0:00:04
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph - --------------------------------------   4% 0:02:08 0:00:04
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph - --------------------------------------   4% 0:01:47 0:00:04
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph -- -------------------------------------   5% 0:01:52 0:00:05
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph -- -------------------------------------   5% 0:01:52 0:00:05
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph -- -------------------------------------   6% 0:02:01 0:00:06
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ---------- -----------------------------  27% 0:02:20 0:00:49
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ----------- ----------------------------  28% 0:02:16 0:00:49
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ----------- ----------------------------  28% 0:02:16 0:00:50
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ----------- ----------------------------  28% 0:02:16 0:00:51
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ----------- ----------------------------  28% 0:02:16 0:00:52
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ----------- ----------------------------  28% 0:02:16 0:00:52
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ----------- ----------------------------  29% 0:02:11 0:00:53
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ----------- ----------------------------  29% 0:02:11 0:00:53
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ----------- ----------------------------  29% 0:02:11 0:00:54
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ----------- ----------------------------  29% 0:02:11 0:00:55
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ----------- ----------------------------  29% 0:02:11 0:00:56
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ----------- ----------------------------  29% 0:02:18 0:00:56
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ----------- ----------------------------  29% 0:02:18 0:00:57
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ----------- ----------------------------  29% 0:02:18 0:00:58
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ----------- ----------------------------  29% 0:02:18 0:00:59
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ------------ ---------------------------  30% 0:02:39 0:01:00
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ------------ ---------------------------  31% 0:02:29 0:01:00
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ------------ ---------------------------  31% 0:02:29 0:01:01
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ------------ ---------------------------  31% 0:02:29 0:01:02
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ------------ ---------------------------  31% 0:02:29 0:01:03
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ------------ ---------------------------  31% 0:02:29 0:01:04
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ------------ ---------------------------  31% 0:02:38 0:01:04
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ------------- --------------------------  33% 0:02:14 0:01:05
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ------------- --------------------------  33% 0:02:14 0:01:05
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ------------- --------------------------  33% 0:02:14 0:01:06
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ------------- --------------------------  33% 0:02:14 0:01:07
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ------------- --------------------------  33% 0:02:14 0:01:08
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ------------- --------------------------  34% 0:02:29 0:01:09
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph ------------- --------------------------  35% 0:02:20 0:01:09
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# └── extract_graph -------------- -------------------------  35% 0:02:14 0:01:10
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ...
# ├── finalize_graph --------------------------------------- 100% 0:00:00 0:00:00
# ├── create_communities ----------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_text_units ------------------------------ 100% 0:00:00 0:00:00
# ├── create_community_reports ----------------------------- 100% 0:00:00 0:00:00
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ├── extract_graph ---------------------------------------- 100% 0:00:00 0:00:00
# ├── finalize_graph --------------------------------------- 100% 0:00:00 0:00:00
# ├── create_communities ----------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_text_units ------------------------------ 100% 0:00:00 0:00:00
# ├── create_community_reports ----------------------------- 100% 0:00:00 0:00:00
# └── generate_text_embeddings -- --------------------------  10% -:--:-- 0:00:00
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ├── extract_graph ---------------------------------------- 100% 0:00:00 0:00:00
# ├── finalize_graph --------------------------------------- 100% 0:00:00 0:00:00
# ├── create_communities ----------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_text_units ------------------------------ 100% 0:00:00 0:00:00
# ├── create_community_reports ----------------------------- 100% 0:00:00 0:00:00
# └── generate_text_embeddings ----------- -----------------  40% 0:00:01 0:00:00
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ├── extract_graph ---------------------------------------- 100% 0:00:00 0:00:00
# ├── finalize_graph --------------------------------------- 100% 0:00:00 0:00:00
# ├── create_communities ----------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_text_units ------------------------------ 100% 0:00:00 0:00:00
# ├── create_community_reports ----------------------------- 100% 0:00:00 0:00:00
# └── generate_text_embeddings -------------- --------------  50% 0:00:01 0:00:00
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ├── extract_graph ---------------------------------------- 100% 0:00:00 0:00:00
# ├── finalize_graph --------------------------------------- 100% 0:00:00 0:00:00
# ├── create_communities ----------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_text_units ------------------------------ 100% 0:00:00 0:00:00
# ├── create_community_reports ----------------------------- 100% 0:00:00 0:00:00
# └── generate_text_embeddings -------------------- --------  70% 0:00:01 0:00:00
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ├── extract_graph ---------------------------------------- 100% 0:00:00 0:00:00
# ├── finalize_graph --------------------------------------- 100% 0:00:00 0:00:00
# ├── create_communities ----------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_text_units ------------------------------ 100% 0:00:00 0:00:00
# ├── create_community_reports ----------------------------- 100% 0:00:00 0:00:00
# └── generate_text_embeddings ----------------------- -----  80% 0:00:01 0:00:00
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ├── extract_graph ---------------------------------------- 100% 0:00:00 0:00:00
# ├── finalize_graph --------------------------------------- 100% 0:00:00 0:00:00
# ├── create_communities ----------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_text_units ------------------------------ 100% 0:00:00 0:00:00
# ├── create_community_reports ----------------------------- 100% 0:00:00 0:00:00
# └── generate_text_embeddings ----------------------- -----  80% 0:00:01 0:00:00
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ├── extract_graph ---------------------------------------- 100% 0:00:00 0:00:00
# ├── finalize_graph --------------------------------------- 100% 0:00:00 0:00:00
# ├── create_communities ----------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_text_units ------------------------------ 100% 0:00:00 0:00:00
# ├── create_community_reports ----------------------------- 100% 0:00:00 0:00:00
# └── generate_text_embeddings -------------------------- --  90% 0:00:01 0:00:01
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ├── extract_graph ---------------------------------------- 100% 0:00:00 0:00:00
# ├── finalize_graph --------------------------------------- 100% 0:00:00 0:00:00
# ├── create_communities ----------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_text_units ------------------------------ 100% 0:00:00 0:00:00
# ├── create_community_reports ----------------------------- 100% 0:00:00 0:00:00
# └── generate_text_embeddings -------------------------- --  90% 0:00:01 0:00:01
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ├── extract_graph ---------------------------------------- 100% 0:00:00 0:00:00
# ├── finalize_graph --------------------------------------- 100% 0:00:00 0:00:00
# ├── create_communities ----------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_text_units ------------------------------ 100% 0:00:00 0:00:00
# ├── create_community_reports ----------------------------- 100% 0:00:00 0:00:00
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ├── extract_graph ---------------------------------------- 100% 0:00:00 0:00:00
# ├── finalize_graph --------------------------------------- 100% 0:00:00 0:00:00
# ├── create_communities ----------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_text_units ------------------------------ 100% 0:00:00 0:00:00
# ├── create_community_reports ----------------------------- 100% 0:00:00 0:00:00
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ├── extract_graph ---------------------------------------- 100% 0:00:00 0:00:00
# ├── finalize_graph --------------------------------------- 100% 0:00:00 0:00:00
# ├── create_communities ----------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_text_units ------------------------------ 100% 0:00:00 0:00:00
# ├── create_community_reports ----------------------------- 100% 0:00:00 0:00:00
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ├── extract_graph ---------------------------------------- 100% 0:00:00 0:00:00
# ├── finalize_graph --------------------------------------- 100% 0:00:00 0:00:00
# ├── create_communities ----------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_text_units ------------------------------ 100% 0:00:00 0:00:00
# ├── create_community_reports ----------------------------- 100% 0:00:00 0:00:00
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ├── extract_graph ---------------------------------------- 100% 0:00:00 0:00:00
# ├── finalize_graph --------------------------------------- 100% 0:00:00 0:00:00
# ├── create_communities ----------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_text_units ------------------------------ 100% 0:00:00 0:00:00
# ├── create_community_reports ----------------------------- 100% 0:00:00 0:00:00
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ├── extract_graph ---------------------------------------- 100% 0:00:00 0:00:00
# ├── finalize_graph --------------------------------------- 100% 0:00:00 0:00:00
# ├── create_communities ----------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_text_units ------------------------------ 100% 0:00:00 0:00:00
# ├── create_community_reports ----------------------------- 100% 0:00:00 0:00:00
# ├── generate_text_embeddings ----------------------------- 100% 0:00:00 0:00:00
# 🚀 generate_text_embeddings
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ├── extract_graph ---------------------------------------- 100% 0:00:00 0:00:00
# ├── finalize_graph --------------------------------------- 100% 0:00:00 0:00:00
# ├── create_communities ----------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_text_units ------------------------------ 100% 0:00:00 0:00:00
# ├── create_community_reports ----------------------------- 100% 0:00:00 0:00:00
# ├── generate_text_embeddings ----------------------------- 100% 0:00:00 0:00:00
# {'text_unit.text':                                                     id
# embedding
# 0    7a17fa7360ff1646ca4683384ceb616e20e1ed70c35f4d...  [0.0076277595944702625,
# 0.005991319660097361, ...
# 1    d622a9906b41290d8195b66f751e34a17876b2fc65210f...  [0.00881952978670597,
# 0.02244037389755249, 0.0...
# 2    20eda504be9853e5ddd93d6f5fa0a54ea639d58decbd4b...  [0.024951636791229248,
# 0.0465664267539978, 0.0...
# 3    4c44882eb785628ae564fc7628f879705e19cc2c73d656...  [0.01655149646103382,
# 0.009829618036746979, 0....
# 4    9db4b517df282c884b1e015bd3ae2b7bec3b26498c5c0b...  [0.024225233122706413,
# 0.013978270813822746, 0...
# ..                                                 ...
# ...
# 151  6a913be02aa839d968be590f6ae0b507d4ac646228f2ac...  [0.01837424747645855,
# 0.03740820661187172, 0.0...
# 152  cdd76e9f3ab4cab0b3e00fe2f8407d316b7a76e243031a...  [-0.028728654608130455,
# 0.0033084352035075426,...
# 153  34c815fec7550459d4cd710d8d4650a94a9b25f1cc44e4...  [-0.004746919497847557,
# -0.011505699716508389,...
# 154  85ca60895cbbe8aac606c59073f2846d75dba4ee78dbce...  [0.004401404410600662,
# 0.013822481036186218, 0...
# 155  91ff3176f0a613e0398839419ecc41b2a335dc74f56cc9...  [-0.006073834840208292,
# 0.010620273649692535, ...
#
# [156 rows x 2 columns], 'entity.description':
# id                                          embedding
# 0   97842ca7-b7ff-41ea-b9e9-d0cb99aa5d27  [-0.014174929820001125,
# 0.02421082928776741, 0...
# 1   99829287-5475-4380-8052-f768af9cb690  [-0.013790852390229702,
# -0.002840244909748435,...
# 2   f7ce051c-bcb2-40d4-859a-8d2bdfc77836  [-0.02809242531657219,
# 0.004912937991321087, 0...
# 3   9ef52d56-3c49-44dd-b294-2aead4c71574  [-0.02818005532026291,
# 0.037999168038368225, 0...
# 4   cff661eb-08da-4580-a2c1-1d11a5a6c9dc  [-0.004399471916258335,
# 0.011177942156791687, ...
# 5   fb288cc2-bfc7-4ef4-a0d6-de2212f1d3a2  [-0.016605187207460403,
# 0.01817992702126503, 0...
# 6   1c088aef-3333-493c-a400-d40991216c39  [0.01761220395565033,
# 0.01311615388840437, 0.0...
# 7   d80c5ed2-6d24-4a32-9c7e-b96e21dec445  [-0.00900360383093357,
# 0.02166292443871498, -0...
# 8   a1f944ba-d6e6-427b-8b0c-1a1c0c58bdda  [-0.017933106049895287,
# 0.04588421806693077, -...
# 9   eef4ceb5-763a-4f74-95d1-93837da60eca  [-0.0147539172321558,
# -0.014239385724067688, 0...
# 10  dbb3199f-5418-416a-90a7-f0230418512a  [-0.011044945567846298,
# 0.03641191124916077, 0..., 'community.full_content':
# id                                          embedding
# 0  22dbffed19a84920886dfe9dcd8b3fd3  [-0.01547054760158062,
# 0.04356904700398445, 0....
# 1  6ec4852be6454ac383ac79de198fcbab  [-0.012800147756934166,
# 0.03788526728749275, 0...}
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ├── extract_graph ---------------------------------------- 100% 0:00:00 0:00:00
# ├── finalize_graph --------------------------------------- 100% 0:00:00 0:00:00
# ├── create_communities ----------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_text_units ------------------------------ 100% 0:00:00 0:00:00
# ├── create_community_reports ----------------------------- 100% 0:00:00 0:00:00
# ├── generate_text_embeddings ----------------------------- 100% 0:00:00 0:00:00
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) - 100%  0…
# ├── create_base_text_units ------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_documents ------------------------------- 100% 0:00:00 0:00:00
# ├── extract_graph ---------------------------------------- 100% 0:00:00 0:00:00
# ├── finalize_graph --------------------------------------- 100% 0:00:00 0:00:00
# ├── create_communities ----------------------------------- 100% 0:00:00 0:00:00
# ├── create_final_text_units ------------------------------ 100% 0:00:00 0:00:00
# ├── create_community_reports ----------------------------- 100% 0:00:00 0:00:00
# ├── generate_text_embeddings ----------------------------- 100% 0:00:00 0:00:00
# 🚀 All workflows completed successfully.
# [2025-05-16T09:05:02Z WARN  lance::dataset::write::insert] No existing dataset at C:\Users\User\Desktop\DeepLearning\17번\langchain-tutorial-main\Ch05. GraphRAG\working_directory\output\lancedb\default-text_unit-text.lance, it will be created
# [2025-05-16T09:05:04Z WARN  lance::dataset::write::insert] No existing dataset at C:\Users\User\Desktop\DeepLearning\17번\langchain-tutorial-main\Ch05. GraphRAG\working_directory\output\lancedb\default-entity-description.lance, it will be created
# [2025-05-16T09:05:04Z WARN  lance::dataset::write::insert] No existing dataset at C:\Users\User\Desktop\DeepLearning\17번\langchain-tutorial-main\Ch05. GraphRAG\working_directory\output\lancedb\default-community-full_content.lance, it will be created

# %%
# working_directory 폴더를 구글 드라이브로 복사
# !cp -r /content/working_directory "/content/drive/My Drive/"
